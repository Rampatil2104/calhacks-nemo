# %%
# %pip -q install openai
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# --- Colab setup: installs ---
# !pip -q install fastapi uvicorn nest-asyncio pyngrok==7.* websockets==12.* requests pydub numpy openai==1.* python-dotenv ffmpeg-python

# --- Imports ---
import os, json, base64, time, asyncio, nest_asyncio, requests, subprocess, tempfile
from datetime import datetime
from typing import Optional
from collections import deque
from io import BytesIO
import re

from fastapi import FastAPI, Request
from fastapi.responses import PlainTextResponse
import uvicorn
from pyngrok import ngrok
from pydub import AudioSegment
from openai import OpenAI

# --- 🔧 Configuration (EDIT THESE) ---
RECALL_API_KEY    = os.getenv("RECALLAI_API_KEY")
OPENAI_API_KEY    = os.getenv("OPENAI_API_KEY")
NGROK_AUTHTOKEN   = os.getenv("NGROK_AUTHTOKEN")
ELEVENLABS_API_KEY = os.getenv("ELEVENLABS_API_KEY")

MEETING_URL       = os.getenv("MEETING_URL", "https://meet.google.com/qey-yfwq-xeu")  # ← put your Meet link here
WAKE_WORD         = os.getenv("WAKE_WORD", "nemo").lower()                       # ← say this to trigger
OPENAI_MODEL      = os.getenv("OPENAI_MODEL", "gpt-5-nano")                               # any Responses-capable model
OPENAI_TTS_MODEL  = os.getenv("OPENAI_TTS_MODEL", "gpt-4o-mini-tts")
OPENAI_TTS_VOICE  = os.getenv("OPENAI_TTS_VOICE", "alloy")                             # pick a voice you like

# --- States ---
PARTIAL_WINDOW_SEC = 20.0
SILENCE_TIMEOUT_SEC = 2.0  # Time to wait after last speech before finalizing (reduced for faster response)
MAX_QUESTION_CHARS = 400

class CaptureState:
    IDLE = "idle"
    CAPTURING = "capturing"

# State tracking
state = CaptureState.IDLE
captured_utterances = []  # Store only FINAL utterances, not partials
last_utterance_ts: float = 0.0
last_capture_end_ts: float = 0.0

# --- FastAPI app ---
app = FastAPI()

@app.get("/", response_class=PlainTextResponse)
def root():
    return "Recall live bot is up"

# --- Transcript cleaning ---
import re
def clean_transcript_text(raw: str) -> str:
    text = raw.replace("’", "'").replace("`", "'")
    text = re.sub(r"([a-z])([A-Z])", r"\1 \2", text)
    text = re.sub(r"([.?!])([A-Za-z])", r"\1 \2", text)
    text = re.sub(r"([a-z])([0-9A-Z])", r"\1 \2", text)
    text = re.sub(r"([0-9])([A-Za-z])", r"\1 \2", text)
    text = re.sub(r"\s+", " ", text)
    return text.strip()

# --- Webhook handler ---
@app.post("/rt")
async def rt_webhook(req: Request):
    """
    Handles live transcription events from Recall/Deepgram.
    State machine: IDLE -> hear wake word -> CAPTURING -> collect utterances -> timeout -> process
    Only uses final utterances (transcript.data), ignoring partials to avoid duplicates.
    """
    try:
        data = await req.json()
        event = data.get("event", "")
        if event not in ("transcript.partial_data", "transcript.data"):
            return {"ok": True}

        payload = data.get("data", {}).get("data", {})
        participant = payload.get("participant", {})
        raw_text = payload.get("text") or " ".join(
            w.get("text", "") for w in payload.get("words", [])
        )
        if not raw_text:
            return {"ok": True}

        text = clean_transcript_text(raw_text)
        speaker = participant.get("name", "unknown")
        now = time.time()

        global state, captured_utterances, last_utterance_ts, last_capture_end_ts

        # --- Handle partial data (just for monitoring, don't process) ---
        if event == "transcript.partial_data":
            print(f"[Partial] {speaker}: {text}")
            return {"ok": True}

        # --- Handle final utterance (only process these to avoid duplicates) ---
        if event == "transcript.data":
            print(f"[Utterance] {speaker}: {text}")
            
            if not text.strip():
                return {"ok": True}

            lower = text.lower()
            
            # --- State: IDLE - listening for wake word ---
            if state == CaptureState.IDLE:
                if WAKE_WORD in lower:
                    # Debounce: avoid triggering too soon after last capture
                    if now - last_capture_end_ts < 2.0:
                        print(f"[Wake] Ignoring '{WAKE_WORD}' - too soon after last capture")
                        return {"ok": True}
                    
                    print(f"[Wake] Heard '{WAKE_WORD}' - starting capture")
                    state = CaptureState.CAPTURING
                    captured_utterances.clear()
                    last_utterance_ts = now
                    
                    # Check if question is in same utterance (after wake word)
                    parts = lower.split(WAKE_WORD, maxsplit=1)
                    if len(parts) > 1:
                        after_wake = parts[1].strip()
                        # Remove common punctuation
                        after_wake = after_wake.strip('.,!?;:')
                        if after_wake and len(after_wake) > 1:
                            captured_utterances.append(after_wake)
                            print(f"[Capture] Got initial text: {after_wake}")
                    
                return {"ok": True}
            
            # --- State: CAPTURING - accumulating utterances ---
            if state == CaptureState.CAPTURING:
                last_utterance_ts = now
                
                # Check for immediate finalization with "please" or similar end markers
                ends_with_please = re.search(r'\bplease[.?!,;:\s]*$', lower)
                ends_with_question = text.strip().endswith('?')
                
                # Don't re-capture the wake word if it appears again
                if WAKE_WORD not in lower:
                    # Check if "please" is in the middle of the utterance
                    if 'please' in lower and not ends_with_please:
                        # Split on "please" and take everything before it
                        before_please = re.split(r'\bplease\b', text, flags=re.I, maxsplit=1)[0].strip()
                        if before_please:
                            captured_utterances.append(before_please)
                            print(f"[Capture] Added (before 'please'): {before_please[:80]}")
                        
                        # Finalize immediately
                        asyncio.create_task(finalize_question_now())
                        return {"ok": True}
                    
                    captured_utterances.append(text.strip())
                    print(f"[Capture] Added: {text[:80]}")
                    
                    # Check for end markers
                    if ends_with_please or ends_with_question:
                        print(f"[Capture] Detected end marker, finalizing...")
                        asyncio.create_task(finalize_question_now())
                        return {"ok": True}
                
                # Check for silence timeout in background
                asyncio.create_task(check_capture_timeout())
                
                return {"ok": True}

        return {"ok": True}

    except Exception as e:
        print("[Webhook Error]", e)
        return {"error": str(e)}


async def finalize_question_now():
    """
    Immediately finalize the captured question (called when end marker detected).
    """
    global state, captured_utterances, last_capture_end_ts
    
    if state == CaptureState.CAPTURING and captured_utterances:
        question = " ".join(captured_utterances).strip()
        
        # Clean up "please" remnants and punctuation
        question = re.sub(r'\bplease[.?!,;:\s]*$', '', question, flags=re.I).strip()
        
        print(f"[Finalized Question] {question}")
        
        # Reset state
        state = CaptureState.IDLE
        last_capture_end_ts = time.time()
        captured_utterances.clear()
        
        # Process the question
        asyncio.create_task(handle_question_and_speak(question))


async def check_capture_timeout():
    """
    Background task to check if we should finalize the captured question
    after a period of silence.
    """
    global state, captured_utterances, last_utterance_ts, last_capture_end_ts
    
    await asyncio.sleep(SILENCE_TIMEOUT_SEC + 0.5)
    
    if state == CaptureState.CAPTURING:
        time_since_last = time.time() - last_utterance_ts
        
        if time_since_last >= SILENCE_TIMEOUT_SEC:
            # Finalize the question
            if captured_utterances:
                question = " ".join(captured_utterances).strip()
                
                # Clean up "please" remnants and punctuation
                question = re.sub(r'\bplease[.?!,;:\s]*$', '', question, flags=re.I).strip()
                
                print(f"[Finalized Question (timeout)] {question}")
                
                # Reset state
                state = CaptureState.IDLE
                last_capture_end_ts = time.time()
                captured_utterances.clear()
                
                # Process the question
                asyncio.create_task(handle_question_and_speak(question))
            else:
                print("[Capture] Timeout but no utterances captured")
                state = CaptureState.IDLE

# --- OpenAI client ---
client = OpenAI(api_key=OPENAI_API_KEY)

conversation_history = deque(maxlen=5)


# --- Heuristic classifier for MCP routing ---
def requires_mcp(question: str) -> bool:
    """
    Simple keyword-based heuristic for routing to MCP integrations
    (Google Calendar, GitHub, etc.).
    """
    q_lower = question.lower()

    # Calendar-related triggers
    calendar_keywords = [
        "calendar", "meeting", "schedule", "event", "remind", "invite", "zoom", "google meet"
    ]

    # GitHub-related triggers
    github_keywords = [
        "pull request", "commit", "repository", "repo", "branch", "merge",
        "issue", "push", "clone", "code review", "workflow", "action"
    ]

    if any(k in q_lower for k in calendar_keywords + github_keywords):
        return True

    # Also handle explicit “check”, “update”, or “open” requests that look like tool use
    if re.search(r"\b(check|update|create|delete|list|open)\b", q_lower):
        if "calendar" in q_lower or "github" in q_lower:
            return True

    return False


# --- MCP POST helper ---
def call_mcp_endpoint(prompt: str, bot_id: str) -> str:
    try:
        url = "http://100.124.227.16:5001/chat"
        payload = {
            "message": prompt,
            "bot_id": bot_id
        }
        headers = {"Content-Type": "application/json"}
        print("[MCP] Routing question to MCP endpoint...")
        resp = requests.post(url, headers=headers, json=payload, timeout=30)
        if resp.status_code == 200:
            data = resp.json()
            print("[MCP] Response:", json.dumps(data, indent=2))
            # Return stringified text if present
            if isinstance(data, dict):
                return data.get("response") or data.get("message") or str(data)
            return str(data)
        else:
            print("[MCP Error]", resp.status_code, resp.text[:200])
            return "Sorry, I couldn’t reach the MCP service."
    except Exception as e:
        print("[MCP Exception]", e)
        return "There was an error contacting the MCP."


async def call_openai_with_contextual_memory(question: str) -> str:
    try:
        msgs = [{"role": "system", "content": (
            "You are Nemo, a friendly, concise meeting assistant. "
            "Keep answers under 60 words, natural for speech."
        )}]
        for q, a in conversation_history:
            msgs.append({"role": "user", "content": q})
            msgs.append({"role": "assistant", "content": a})
        msgs.append({"role": "user", "content": question})
        print(f"[OpenAI] Searching: {question[:80]}...")
        resp = client.responses.create(model=OPENAI_MODEL, input=msgs)
        out = []
        for i in resp.output:
            if i.type == "message":
                for c in i.content:
                    if c.type == "output_text":
                        out.append(c.text)
        answer = " ".join(out).strip()
        return answer or "Sorry, I’m not sure."
    except Exception as e:
        print("[OpenAI Error]", e)
        return "Sorry, I hit an error."

# --- TTS ---
def elevenlabs_tts_to_mp3_bytes(text: str, voice_id="21m00Tcm4TlvDq8ikWAM") -> bytes:
    try:
        url = f"https://api.elevenlabs.io/v1/text-to-speech/{voice_id}"
        headers = {
            "Accept": "audio/mpeg",
            "xi-api-key": ELEVENLABS_API_KEY,
            "Content-Type": "application/json",
        }
        payload = {"text": text, "model_id": "eleven_multilingual_v2"}
        r = requests.post(url, headers=headers, json=payload, timeout=60)
        if r.status_code != 200:
            print("[TTS Error]", r.status_code, r.text[:200])
            return b""
        return r.content
    except Exception as e:
        print("[TTS Error]", e)
        return b""

# --- Recall output endpoints ---
def recall_output_audio(bot_id: str, mp3_bytes: bytes):
    print("[Recall] Sending TTS audio...")
    b64 = base64.b64encode(mp3_bytes).decode("utf-8")
    url = f"https://us-west-2.recall.ai/api/v1/bot/{bot_id}/output_audio/"
    headers = {"Authorization": RECALL_API_KEY, "content-type": "application/json"}
    payload = {"kind": "mp3", "b64_data": b64}
    requests.post(url, headers=headers, json=payload, timeout=30)


# --- Full pipeline ---
async def handle_question_and_speak(question: str):
    try:
        # Decide whether to route through MCP
        if requires_mcp(question):
            print("[Router] Using MCP for:", question)
            print("[A] On it.")
            # Synchronously call MCP API
            mcp_response = await asyncio.to_thread(call_mcp_endpoint, question, CURRENT_BOT_ID)
            print(f"[MCP Answer] {mcp_response}")
            # No audio output; just continue listening
            return
        else:
            print("[Router] Using LLM for:", question)
            answer = await call_openai_with_contextual_memory(question)
            conversation_history.append((question, answer))
            print(f"[A] {answer}")
            mp3 = await asyncio.to_thread(elevenlabs_tts_to_mp3_bytes, answer)
            if CURRENT_BOT_ID and mp3:
                recall_output_audio(CURRENT_BOT_ID, mp3)
    except Exception as e:
        print("[Pipeline Error]", e)


# --- ngrok + Recall bot setup ---
def start_ngrok(port: int = 8000) -> str:
    ngrok.set_auth_token(NGROK_AUTHTOKEN)
    public_tunnel = ngrok.connect(addr=port, proto="http")
    print(f"[ngrok] Public URL: {public_tunnel.public_url}")
    return public_tunnel.public_url

def create_recall_bot(public_url: str) -> str:
    url = "https://us-west-2.recall.ai/api/v1/bot/"
    headers = {
        "Authorization": RECALL_API_KEY,
        "accept": "application/json",
        "content-type": "application/json",
    }

    SILENT_MP3_B64 = (
        "SUQzAwAAAAAAF1RTU0UAAAAPAAADTGF2ZjU2LjI0LjEwNAAAAAAAAAAAAAAA//tQxAADBQAA"
        "AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA"
        "AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA"
    )

    payload = {
        "meeting_url": MEETING_URL,
        "start_bot": True,
        "bot_name": "Nemo",
        "recording_config": {
            "transcript": {
                "provider": {
                    "deepgram_streaming": {
                        "model": "nova",
                        "language": "en",
                        "punctuate": "true",
                        "smart_format": "true",
                        "vad_turnoff_mode": "none",
                        "endpointing": 5000,
                    }
                },
                "diarization": {
                    "use_separate_streams_when_available": False
                },
            },
            "realtime_endpoints": [
                {
                    "type": "webhook",
                    "url": f"{public_url}/rt",
                    "events": [
                        "transcript.partial_data",
                        "transcript.data",
                    ],
                    "metadata": {},
                }
            ],
            "retention": {"type": "forever"},
        },
        "automatic_audio_output": {
            "in_call_recording": {
                "data": {"kind": "mp3", "b64_data": SILENT_MP3_B64}
            }
        },
    }

    r = requests.post(url, headers=headers, json=payload, timeout=60)
    if r.status_code >= 300:
        raise RuntimeError(f"Failed to create bot: {r.status_code} {r.text}")
    data = r.json()
    print(f"[Recall] Bot created successfully: {data['id']}")
    return data["id"]




# --- Run ---
nest_asyncio.apply()
CURRENT_BOT_ID = None

async def main():
    global CURRENT_BOT_ID
    port = 8000
    public_url = start_ngrok(port)
    CURRENT_BOT_ID = create_recall_bot(public_url)
    print(f"[Ready] Say '{WAKE_WORD}' followed by your question. The bot will capture after {SILENCE_TIMEOUT_SEC}s of silence.")
    config = uvicorn.Config(app, host="0.0.0.0", port=port, log_level="info")
    server = uvicorn.Server(config)
    await server.serve()

await main()
# Out:
# zsh:1: no matches found: pyngrok==7.*
# [ngrok] Public URL: https://unministrative-twirly-ephraim.ngrok-free.dev
# [Recall] Bot created successfully: d24fdc50-eb99-46aa-a55e-c6190f468101
# [Ready] Say 'nemo' followed by your question. The bot will capture after 2.0s of silence.
# INFO:     Started server process [68240]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# t=2025-10-26T04:00:12-0700 lvl=warn msg="failed to check for update" obj=updater err="Post \"https://update.equinox.io/check\": context deadline exceeded"
# [Partial] Ishan Buyyanapragada: Hello.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Hello?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hello. Hello.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hello. Hello. Hello. Hello.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Hello. Hello. Hello. Hello.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo. Can
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo. Can you create for me a
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, NEEMO. Can you create for me a calendar event at five
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Hey, NEEMO. Can you create for me a calendar event at
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: 5 PM, Wednesday,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: 5 PM, Wednesday next week.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: 5 PM, Wednesday next week.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, NEEMO.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, NEEMO. Can you create for
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, NEEMO. Can you create for me a calendar event
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, NEEMO. Can you create for me a calendar event at Wednesday
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Hey, NEEMO. Can you create for me a calendar event at Wednesday next week?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: 4 PM.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: 4 PM.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: 4 PM.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: 4 PM.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Did he end?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Say it again? Hey. Need
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Get again? Hey, Nemo. Can you create
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Say it again?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo. Can you create for me
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo. Can you create for me a calendar event
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, NEEMO. Can you create for me a calendar event at four PM one
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo. Can you create for me a calendar event at 4 PM, Wednesday, next week?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Hey, Nemo. Can you create for me a calendar event at 4 PM, Wednesday, next week?
# [Wake] Heard 'nemo' - starting capture
# [Capture] Got initial text:  can you create for me a calendar event at 4 pm, wednesday, next week
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hello.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hello.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hello?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hello.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Hello?
# [Capture] Added: Hello?
# [Capture] Detected end marker, finalizing...
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Finalized Question] can you create for me a calendar event at 4 pm, wednesday, next week Hello?
# [Router] Using MCP for: can you create for me a calendar event at 4 pm, wednesday, next week Hello?
# [A] On it.
# [MCP] Routing question to MCP endpoint...
# [Partial] Ishan Buyyanapragada: Oh,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I got
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I got it.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Got it.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Got it.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Or maybe maybe
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Or maybe maybe I'm just not gonna talk to you.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: They should
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: It should be apple's probably wondering.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: It should be apple, the primary one. Right?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: And this is fine
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: This is fine.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: This is fine. Thank you. Let's
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: This is fine.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Looks looking at normal to
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Looks looking normal to me. We try
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Looks looking that normal to me. You're trying in. It
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Looks looking that normal to me, reaching in.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hitting it?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hitting it?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hitting it? Yeah.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hitting it? Yeah. I need to clean up these log
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Hitting it?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I need to clean up these logs. I'm like,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I need to clean up these logs. I'm like duplicating the logs for now.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I need to clean up these logs. I'm like duplicating the logs for now. That's why
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I need to clean up these logs. I'm like duplicating the logs for now. That's why it's so cluttered.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: I need to clean up these logs. I'm like duplicating the logs for now.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: That's why it's so butter. That's why
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: That's why it's so butter. That's why it looks like you're all in the same
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: That's why it's so cluttered. That's why it looks like you're all in the same shit. Yeah. But it's
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: That's why it's so cluttered. That's why it looks like you're all in the same shape.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [MCP Exception] HTTPConnectionPool(host='100.124.227.16', port=5001): Read timed out. (read timeout=30)
# [MCP Answer] There was an error contacting the MCP.
# [Partial] Ishan Buyyanapragada: Yeah. But it's with this is really just three calls.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah. But it's this is really just three calls. Okay. Okay. Like I said,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah. But it's this is really just three calls. Okay. I guess, like, five to six
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Yeah. But it's this is really just three calls. Okay. Okay. I guess, like,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: five to six closest normal
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: five to six calls is normal. Oh,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: five to six calls is normal. Oh,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I'm gonna get you
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: No. It's
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: No. It's it's same here as last time.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: No. It's it's same here as last time.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: No. It's it's same here as last time.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: No. It's it's same here as last time.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yep.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah. And I don't get my attention to
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah. And I don't get a message.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah. And I don't get my attention to that. This is how it's just gonna not be anything to
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Yeah. And I don't get my attention to that. This is how it's just gonna not be anything to it.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: That
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Back.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: That.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: That.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: This code
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: This products.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Is codecs. Pop ID.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Is codecs. Pop ID.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Is codecs. Pop ID.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Like, what I said last
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Like, what I said last time, you didn't send this.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: What I said last time? I didn't send this.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: What I said last time? I didn't send this.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: The recall
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: The recall API can't find
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: The recall API can't find a bot with that. I
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: The recall API can't find a bot with that item. Okay.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: The recall API can't find a bot with that item.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Advise the lender
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Advise no longer active internet. Like,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Advise no longer active internet. Like,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Advise no longer active internet. Like, if I
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Advise no longer active engineering.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Their fire device could be aided in
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Their fire device created an active adjustment
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Their fire device created an active adjustment for you in both the work
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Their fire device could be a did an active adjustment for you and both the work ready.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: You're expecting.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: You expect it.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: You're expecting.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: You're expecting.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: So that's
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Then you say it from, like,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Then you change it from experience to a set.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Then you change it from experience to a set,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: will I will I
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: will will anything have happened to you guys?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: will will anything have happened to you guys? Oh, I know why.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: will will anything have happened to you guys? Oh, I know why.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: will will anything have happened to you guys? Oh, I know why.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Let me change this API
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Let me change this API.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Let me change this API.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Two two
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Two to mine. So
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Two. To mine.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: So
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Sorry question.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Great question.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Great question.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay. Okay. Okay. Ready. Ready. Ready. It's
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Okay. Okay. Okay. Okay. Ready. Ready. Ready.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: A way of
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: We have activated an ice
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, we have activated and eyes hope it's a problem.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, we have activated, and I still have some problems. You're ready, ready,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Hey, we have activated and eyes hope it's a problem.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: You're ready, ready.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: You're ready, ready. This this is
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: You're ready, ready now. This this is act this actually feels like
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: You're ready already? It's this is act this actually feels like it's a bit. There's no way.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay. Can
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay. Can I just run again?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay. Can I just run again?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Okay. Can I just run again?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hello?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hello? Does it still
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hello? Does it still? Is it
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hello? Does it still? Is it still is this still on?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hello? Does it still? Is it still is this still on?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Hello? Does it still? Is it still is it still on?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo. Can you create for
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo. Can you create for me a calendar event
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, NEEMO. Can you create for me a calendar event on Monday
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Hey, NEEMO. Can you create for me a calendar event on Monday
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: 5 PM next week
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: 5 PM next week. Please
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: 5 PM next week. Please.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo. Can you create
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo. Can you create for me a calendar
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo. Can you create for me a calendar event five PM
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Hey, Nemo. Can you create for me a calendar event
# [Wake] Heard 'nemo' - starting capture
# [Capture] Got initial text:  can you create for me a calendar event
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: 5 PM next week,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: 5 PM next week, Monday, please.
# [Capture] Added: 5 PM next week, Monday, please.
# [Capture] Detected end marker, finalizing...
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Finalized Question] can you create for me a calendar event 5 PM next week, Monday,
# [Router] Using MCP for: can you create for me a calendar event 5 PM next week, Monday,
# [A] On it.
# [MCP] Routing question to MCP endpoint...
# [Partial] Ishan Buyyanapragada: Hey,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: I got it. I got it. Got it.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: We need to
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: We need to and have I had it also
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I'm have I had it also say
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I'm have I had it also say Lima with two reasons
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I'm have I had it also say Lima with two reasons? Okay.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: I'm have I had it also say Lima with two reasons?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay. Yeah. Yeah. Yeah.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Okay. Yeah. Yeah. Yeah. He's telling me to see. Okay.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: This
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: It's better
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: This better be it.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: This better be it.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: From being.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: From being.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: From being.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [MCP Exception] HTTPConnectionPool(host='100.124.227.16', port=5001): Read timed out. (read timeout=30)
# [MCP Answer] There was an error contacting the MCP.
# [Partial] Ishan Buyyanapragada: That
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: That's a lot more than we saw
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: That's a lot more than we send out something. No. This
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: That's a lot more than we sign off center.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: No. This is it's still like six.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: No. This is it's still like six six to nine.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: No. This is it's still like six six to nine.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: It's not fun.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: It's not fun.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: It's not fun.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: It's not fun.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: That's
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay. That is a little
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Okay. That is a little more than
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: normal.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: normal.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: normal.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: normal.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: normal.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Oh,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Oh, so
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Oh, it's been been a lot of calendar
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Oh, it's been a lot of calendar events. Right?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: So
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: For time.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: For time.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: For time.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: By its
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: By good speaking of Grano,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Bye. You're speaking with Briana Munz.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Like, you're speaking with Brandon Moss.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Like, it's picking up Granite Munocks.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: This civilization
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah. This application
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah. This civilization is really fine. Alright. Yeah.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Yeah. I just have a taste in every department. Alright. Yeah.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hello.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay. This is not this is
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay. This is not this is not right. This is
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Okay. This is not this is not right.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: This is too long.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: This is too long.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: This is too long.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: This is too long.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: This is too long. I agree.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: This is too long.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I'm telling this one.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay. One second. Yeah. No. But
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yes. No. But can you
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah. No. But can you ask why that's
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah. No. But can you ask why that sounds?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Yeah. No. But can you ask why that sounds?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Something recently
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Something is a little bit like yeah.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Something recently. Yeah. It's probably
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Something recently. Yeah. It's probably. Okay.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Something recently. Yeah. It's probably
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay. But let's try my time.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Okay. Have you But let's try my time again.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Okay. But let's try my time again.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah. An email.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah. Hey, Nemo. Can you create for me a
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah. Hey, Nemo. Can you create for me a calendar event? My
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Yeah. Hey, Nemo. Can you create for me a calendar event
# [Wake] Heard 'nemo' - starting capture
# [Capture] Got initial text:  can you create for me a calendar event
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Monday, 5 PM, next
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Monday, 5 PM next week.
# [Capture] Added: Monday, 5 PM next week.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Finalized Question (timeout)] can you create for me a calendar event Monday, 5 PM next week.
# [Router] Using MCP for: can you create for me a calendar event Monday, 5 PM next week.
# [A] On it.
# [MCP] Routing question to MCP endpoint...
# [MCP Exception] HTTPConnectionPool(host='100.124.227.16', port=5001): Max retries exceeded with url: /chat (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10c1fb7d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# [MCP Answer] There was an error contacting the MCP.
# [Partial] Ishan Buyyanapragada: Wait. I stopped, sir,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Wait, I stopped the server.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Wait. I stopped the server.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Wait. I stopped the server. Why? Because it was
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Wait. I stopped the server.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Because it was it was the MCC
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Because it was it was the MCP was going on
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Because it was it was the MCP was going on.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Because it was it was the MCP was going on.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: And we spin it back up.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Yeah. Let me spin it back up.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Can we spin it back up?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo. Can you create for me
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo. Can you create for me a calendar event, five
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Hey, Nemo. Can you create for me a calendar event, 5 PM, Monday
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Hey, NEEMO. Can you create for me a calendar event 5 PM Monday next week?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Spell it with two
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Spell it with two rings. Hey.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Spell it with two rings. Hey, Nemo. Can you create
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Spell it with two rings. Hey, Nemo.
# [Wake] Heard 'nemo' - starting capture
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Can you create for me a calendar
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Can you create for me a calendar event five PM
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Can you create for me a calendar event 5 PM Monday
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Can you create for me a calendar event 5 PM Monday's week?
# [Capture] Added: Can you create for me a calendar event 5 PM Monday's week?
# [Capture] Detected end marker, finalizing...
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Finalized Question] Can you create for me a calendar event 5 PM Monday's week?
# [Router] Using MCP for: Can you create for me a calendar event 5 PM Monday's week?
# [A] On it.
# [MCP] Routing question to MCP endpoint...
# [Partial] Ishan Buyyanapragada: I got
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I got it. Okay.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I got it. Okay. It it didn't
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I got it. Okay. It it didn't get next week. It got
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: I got it. Okay.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: It it didn't get next week.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: It it didn't get next week.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: It it didn't get next week.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I will see what it does.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I will see what it does. Yeah.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I will see what it does. Yeah. I mean,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Oh, you'll see what it does.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: It's good. I think it's good.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: It's good. I think it's good to to test it
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: It's good. I think it's good to to test it on the phone. Right? That's
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: It's good. I think it's good to to test it on the phone. Right? That's our system.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: It's good. I think it's good to to test it on the phone. Right? That's our system.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I just
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I just wish we had a better voice mail
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I just wish we had a better voice model, but
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I just wish we had a better voice model.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: I just wish we had a better voice model, but actually
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: speech.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: speech to touch.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: speech to touch.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: speech to touch.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [MCP Exception] HTTPConnectionPool(host='100.124.227.16', port=5001): Read timed out. (read timeout=30)
# [MCP Answer] There was an error contacting the MCP.
# [Utterance] Ishan Buyyanapragada: Rachel sounds great.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Oh, do you know what we need? We do
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Oh, do you know what we need? We do need the zoo.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Oh, do you know what we need? We do need the zoo.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: We still
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: We're still after this initial
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: We're still after this initial message, we're still
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: We still after this initial message, we still need to ask it
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: We're still after this initial message,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: You still need to ask it. I
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: You still need to ask it.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I still have
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I still have the same error, such
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I still have the same error. So I changed the API.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I still have the same error, so I changed the API. So
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: I still have the same error. So I changed the API.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: On your end too.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: On your end too. Right? Yes. On my
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: On your end too. Right? Yes. On my end too. Let's
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: On your end too. Right? Yes. On my end too.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I still have the same error.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I still have the same error. Okay.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I still have the same error. Okay.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I still have the same error. Okay. Any way
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: I still have the same error. Okay.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Anywhere else?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Anywhere else, you would have that impact
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Anywhere else you would have that impact free?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Any way
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Anywhere else you would talk
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: And you were also with hard coding broad ID
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: And you were also with hard coding Broad ID for Mister
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: And you were also with hard coding bot ID for
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Mister Sutchford. We
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Mister Suttgart. Wait. That okay.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Mister Suttford. Wait.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I find it really
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: That I find it really odd that we have not gotten
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: That I find it really odd that we have not gotten. Like, we
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: That I find it really odd that we have not gotten
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Like, we had it's
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Like, we had it received extended
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Like, we had it received extended a text after
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Like, we had it received extended a text pop in that one time.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: But other we
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: But are there we did find it or we didn't?
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: But are there we did find it or we didn't? No. Like, it
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: But are there we did find it or we didn't? No. Like, what's that one time? It
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: But are there we did find it or we didn't? No. Like, it worked that one time.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Did. Yeah. But I
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Did. Yeah. But I think it was hard
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Did. Yeah. But I think it was hard coded, which
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Did. Yeah. But I think it was hard coded, which I guess helped.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Did. Yeah. But I think it was hard coded, which I guess helped. The
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Did. Yeah. But I think it was hard coded, which I guess helped.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: To make sure I
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Let me try to hard code it again. I mean,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Let me try to hard code it again. I mean, I wasn't really
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Let me try to hard code it again. I mean, I was immediately.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: So
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Maybe if the payload is wrong,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Maybe if the payload is wrong.
# ...
# [Partial] Ishan Buyyanapragada: One more pathway. Finish website and
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: One more pathway. Finish website and
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: One more pathway. Finish website and and I'll do MTP. If you wanna
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: One more pathway. Finish website and
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: and I'll do MTP. If you wanna take
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: and I'll do MTP. If you wanna take an app, I can do MTP right now,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I'll do MTP. If you wanna take an app, I can't answer right now, and then we can do
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: I'll do MTP. If you wanna take a nap, I can MTP right now, and then we can do a new income. I'll take, like,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: I'll do MTP. If you wanna take an app, I can't answer right now, and then we can
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: do when you wake up? I'll take, like, a fifth
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: do when you wake up? I'll take, like, a fifteen minute nap.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: do when you wake up? I'll take, like, a fifteen minute nap. Yeah. I think this is yeah. You could
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: do when you wake up? I'll take, like, a fifteen minute nap. Yeah. I think you should, yeah, you could sleep. You could sleep because you
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: do when you wake up? I'll take, like, a fifteen minute nap. Yeah. I think you should, yeah, you could sleep. You could sleep.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Because you look tired.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Because you got tired, sir. You too.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Because you got tired, sir. You too, bro. You should
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Because you got tired, sir. You Tube, ma'am. You should
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Because you got tired, sir. You Tube, ma'am.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Three one
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: So we will have to know what more information we are
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: So, anyway, I don't know what more information we are in tonight.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: So we don't know what more information we are in today. Now that we have now that
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: So, anyway, I don't know what more information we are in tonight.
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Now that we have now that we are
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Partial] Ishan Buyyanapragada: Now that we have now that we are always close to being
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# [Utterance] Ishan Buyyanapragada: Now that we have now that we are always close to being done with the action,
# INFO:     54.218.105.73:0 - "POST /rt HTTP/1.1" 200 OK
# t=2025-10-26T04:32:01-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read EOF from remote peer"
# t=2025-10-26T04:32:11-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=884aafe1a82f clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T04:47:39-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:57641->3.136.132.147:443: read: connection reset by peer"
# t=2025-10-26T04:47:54-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=dd289c009420 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T04:53:02-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:57758->3.12.62.205:443: read: connection reset by peer"
# t=2025-10-26T04:53:17-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=29eac638d208 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T04:55:08-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read EOF from remote peer"
# t=2025-10-26T04:55:25-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=adc0cceba3b2 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T05:10:55-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:57887->52.8.220.142:443: read: connection reset by peer"
# t=2025-10-26T05:11:10-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=dc1d328755a8 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T05:14:52-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:57962->50.18.185.122:443: read: connection reset by peer"
# t=2025-10-26T05:15:05-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=3abb92c92dcb clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T05:24:13-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:58074->54.177.106.231:443: read: connection reset by peer"
# t=2025-10-26T05:24:27-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=2c719fc01dad clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T05:26:19-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read EOF from remote peer"
# t=2025-10-26T05:26:35-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=0b37e15aed4f clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T05:27:51-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:58287->3.136.132.147:443: read: connection reset by peer"
# t=2025-10-26T05:28:05-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=62e4bbd8d799 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T05:41:23-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:58300->54.177.106.231:443: read: connection reset by peer"
# t=2025-10-26T05:41:23-0700 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.ngrok-agent.com:443\": dial tcp [2600:1f1c:d8:5f00:cd90:4abd:8e45:ba43]:443: connect: no route to host"
# t=2025-10-26T05:41:24-0700 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.ngrok-agent.com:443\": dial tcp [2600:1f1c:d8:5f00:cd90:4abd:8e45:ba43]:443: connect: no route to host"
# t=2025-10-26T05:41:25-0700 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="failed to dial ngrok server with address \"connect.ngrok-agent.com:443\": dial tcp [2600:1f1c:d8:5f00:cd90:4abd:8e45:ba43]:443: connect: no route to host"
# t=2025-10-26T05:41:26-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=61d5dcc894bb clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T05:42:42-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read EOF from remote peer"
# t=2025-10-26T05:42:48-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=312b0df6c849 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T05:46:19-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:59145->3.12.62.205:443: read: connection reset by peer"
# t=2025-10-26T05:46:34-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=be299ad1e5e9 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T05:47:35-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read EOF from remote peer"
# t=2025-10-26T05:47:46-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=50c242b8d7b8 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T05:48:41-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read EOF from remote peer"
# t=2025-10-26T05:49:00-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=394d0a6bbc23 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T05:52:35-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:59348->54.183.110.234:443: read: connection reset by peer"
# t=2025-10-26T05:52:50-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=7cac1a023b7a clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T05:54:01-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read EOF from remote peer"
# t=2025-10-26T05:54:18-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=659143705993 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T05:55:11-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read EOF from remote peer"
# t=2025-10-26T05:55:26-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=d40da4579bd8 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T06:02:42-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:59466->54.183.110.234:443: read: connection reset by peer"
# t=2025-10-26T06:02:57-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=371d5ccc0915 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T06:07:45-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:59597->54.177.106.231:443: read: connection reset by peer"
# t=2025-10-26T06:08:00-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=ad0503456126 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T06:09:57-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read EOF from remote peer"
# t=2025-10-26T06:10:02-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=3b57a3a4ef45 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T06:12:04-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=2a72cc6f77a3 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T06:12:04-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="session closed"
# t=2025-10-26T06:13:51-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read EOF from remote peer"
# t=2025-10-26T06:14:13-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=99a78cd117f1 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T06:15:06-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read EOF from remote peer"
# t=2025-10-26T06:15:15-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=d5fae2bce471 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T06:17:46-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:59950->3.136.132.147:443: read: connection reset by peer"
# t=2025-10-26T06:18:01-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=e4b278e3bad1 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T06:28:15-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:59982->3.16.250.205:443: read: connection reset by peer"
# t=2025-10-26T06:28:30-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=934598a8a46e clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T06:36:49-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:60166->54.183.110.234:443: read: connection reset by peer"
# t=2025-10-26T06:37:04-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=b6f479b3b2a3 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T06:37:55-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read EOF from remote peer"
# t=2025-10-26T06:38:11-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=0071ae9d7835 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T06:39:01-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read EOF from remote peer"
# t=2025-10-26T06:39:19-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=62a1560388e6 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T06:56:26-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:60300->3.12.62.205:443: read: connection reset by peer"
# t=2025-10-26T06:56:41-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=b99014319030 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T06:59:17-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:60329->50.18.248.6:443: read: connection reset by peer"
# t=2025-10-26T06:59:32-0700 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=b8c015444090 clientid=fabe27f627f878a8f32b4de776b67e05
# t=2025-10-26T07:16:38-0700 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=59cf9f31b0a2 err="read tcp 10.72.3.8:60414->54.183.110.234:443: read: connection reset by peer"
# t=2025-10-26T07:16:48-0700 lvl=warn msg="Stopping forwarder" name=http-8000-ffb0f498-ab5f-494d-92f0-b875ea819cf1 acceptErr="failed to accept connection: Listener closed"
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [68240]

# %%
from pyngrok import ngrok
ngrok.kill()  # kills all active ngrok sessions

# %%
public_url = start_ngrok(8000)
# Out:
# [ngrok] Public URL: https://unministrative-twirly-ephraim.ngrok-free.dev
